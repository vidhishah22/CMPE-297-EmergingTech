# %% [markdown]
# Medium Post https://medium.com/@lawrencedikeu/easy-neural-style-transfer-with-google-colab-a3264789d6ed

# %%
# !rm -r ComputerVision NeuralStyleTransfer
# !git clone https://github.com/ldfrancis/ComputerVision.git
# !cp -r ComputerVision/NeuralStyleTransfer .
# !pip uninstall scipy
# !pip install scipy==1.1.0
# Out:
# Cloning into 'ComputerVision'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 676 (delta 22), reused 45 (delta 10), pack-reused 603
# Receiving objects: 100% (676/676), 32.20 MiB | 22.72 MiB/s, done.
# Resolving deltas: 100% (303/303), done.
# Uninstalling scipy-1.1.0:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/scipy-1.1.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/scipy/*
# Proceed (y/n)? y
#   Successfully uninstalled scipy-1.1.0
# Collecting scipy==1.1.0
#   Using cached https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.17.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
# Successfully installed scipy-1.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
CONTENT_IMAGE = "content.jpeg" 
STYLE_IMAGE = "style.jpeg"
IMAGE_HEIGHT = 428
IMAGE_WIDTH = 612
ITERATION = 200

# %%
path_to_content_image = "/content/drive/Shared drives/TA/Assignment-4/Style Transfer/"+CONTENT_IMAGE
path_to_style_image = "/content/drive/Shared drives/TA/Assignment-4/Style Transfer/"+STYLE_IMAGE

# %%
import matplotlib.pyplot as plt
c_image = plt.imread(path_to_content_image)
s_image = plt.imread(path_to_style_image)

# %%
print("Content Image of size (height, width) => {0}".format(c_image.shape[:-1]))
plt.imshow(c_image)
# Out:
# Content Image of size (height, width) => (428, 612)

# %%
print("Style Image of size (height, width) => {0}".format(s_image.shape[:-1]))
plt.imshow(s_image)
# Out:
# Style Image of size (height, width) => (428, 612)

# %%
from NeuralStyleTransfer import implementNTS as NST
NST.setImageDim(IMAGE_WIDTH,IMAGE_HEIGHT)
NST.run(ITERATION, style_image=path_to_style_image, content_image=path_to_content_image)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:316: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# downloading...
# *done*
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:202: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:331: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:353: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Iteration 20 :
# total cost = 145584870000.0
# content cost = 17327.547
# style cost = 1418507500.0
# total variational loss =  18669878.0
# Time elapsed:  10.16809344291687
# Iteration 40 :
# total cost = 77105770000.0
# content cost = 19672.342
# style cost = 731021000.0
# total variational loss =  20017620.0
# Time elapsed:  5.154514789581299
# Iteration 60 :
# total cost = 46358966000.0
# content cost = 21162.004
# style cost = 423433280.0
# total variational loss =  20077380.0
# Time elapsed:  5.169304370880127
# Iteration 80 :
# total cost = 31351378000.0
# content cost = 22154.428
# style cost = 274477400.0
# total variational loss =  19517356.0
# Time elapsed:  5.141935348510742
# Iteration 100 :
# total cost = 22906350000.0
# content cost = 22737.69
# style cost = 191735140.0
# total variational loss =  18663332.0
# Time elapsed:  5.239586591720581
# Iteration 120 :
# total cost = 17665913000.0
# content cost = 23112.637
# style cost = 141294540.0
# total variational loss =  17681428.0
# Time elapsed:  5.162549734115601
# Iteration 140 :
# total cost = 14228472000.0
# content cost = 23400.744
# style cost = 108930664.0
# total variational loss =  16676154.0
# Time elapsed:  5.16923713684082
# Iteration 160 :
# total cost = 11840543000.0
# content cost = 23614.557
# style cost = 87023100.0
# total variational loss =  15690278.0
# Time elapsed:  5.1381824016571045
# Iteration 180 :
# total cost = 10099706000.0
# content cost = 23791.418
# style cost = 71507920.0
# total variational loss =  14743674.0
# Time elapsed:  5.130402088165283
# Iteration 200 :
# total cost = 8777146000.0
# content cost = 23962.623
# style cost = 60057550.0
# total variational loss =  13856055.0
# Time elapsed:  5.231555938720703

# %%
generated_image_path = "/content/NeuralStyleTransfer/output/generated_image.jpg"
image = plt.imread(generated_image_path)
plt.imshow(image)
